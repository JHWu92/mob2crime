# %%
import geopandas as gp
# %matplotlib inline
import pandas as pd

# %%
import folium
from src.utils.map_vis import geojson_per_row

# %% [markdown]
# # Mexico

# %%
# https://gist.github.com/xijo/d4bad3953f7b9979dd91
REPLACEMENTS = {
    "â‚¬": "€", "â€š": "‚", "â€ž": "„", "â€¦": "…", "Ë†" : "ˆ",
    "â€¹": "‹", "â€˜": "‘", "â€™": "’", "â€œ": "“", "â€" : "”",
    "â€¢": "•", "â€“": "–", "â€”": "—", "Ëœ" : "˜", "â„¢": "™",
    "â€º": "›", "Å“" : "œ", "Å’" : "Œ", "Å¾" : "ž", "Å¸" : "Ÿ",
    "Å¡" : "š", "Å½" : "Ž", "Â¡" : "¡", "Â¢" : "¢", "Â£" : "£",
    "Â¤" : "¤", "Â¥" : "¥", "Â¦" : "¦", "Â§" : "§", "Â¨" : "¨",
    "Â©" : "©", "Âª" : "ª", "Â«" : "«", "Â¬" : "¬", "Â®" : "®",
    "Â¯" : "¯", "Â°" : "°", "Â±" : "±", "Â²" : "²", "Â³" : "³",
    "Â´" : "´", "Âµ" : "µ", "Â¶" : "¶", "Â·" : "·", "Â¸" : "¸",
    "Â¹" : "¹", "Âº" : "º", "Â»" : "»", "Â¼" : "¼", "Â½" : "½",
    "Â¾" : "¾", "Â¿" : "¿", "Ã€" : "À", "Ã‚" : "Â", "Ãƒ" : "Ã",
    "Ã„" : "Ä", "Ã…" : "Å", "Ã†" : "Æ", "Ã‡" : "Ç", "Ãˆ" : "È",
    "Ã‰" : "É", "ÃŠ" : "Ê", "Ã‹" : "Ë", "ÃŒ" : "Ì", "ÃŽ" : "Î",
    "Ã‘" : "Ñ", "Ã’" : "Ò", "Ã“" : "Ó", "Ã”" : "Ô", "Ã•" : "Õ",
    "Ã–" : "Ö", "Ã—" : "×", "Ã˜" : "Ø", "Ã™" : "Ù", "Ãš" : "Ú",
    "Ã›" : "Û", "Ãœ" : "Ü", "Ãž" : "Þ", "ÃŸ" : "ß", "Ã¡" : "á",
    "Ã¢" : "â", "Ã£" : "ã", "Ã¤" : "ä", "Ã¥" : "å", "Ã¦" : "æ",
    "Ã§" : "ç", "Ã¨" : "è", "Ã©" : "é", "Ãª" : "ê", "Ã«" : "ë",
    "Ã¬" : "ì", "Ã­"  : "í", "Ã®" : "î", "Ã¯" : "ï", "Ã°" : "ð",
    "Ã±" : "ñ", "Ã²" : "ò", "Ã³" : "ó", "Ã´" : "ô", "Ãµ" : "õ",
    "Ã¶" : "ö", "Ã·" : "÷", "Ã¸" : "ø", "Ã¹" : "ù", "Ãº" : "ú",
    "Ã»" : "û", "Ã¼" : "ü", "Ã½" : "ý", "Ã¾" : "þ", "Ã¿" : "ÿ"
  }

# %%
# http://www.inegi.org.mx/geo/contenidos/geoestadistica/m_g_0.aspx
shp_urban = gp.read_file('data/mexico/mglu2014v6_2/mglu2015v6_2.shp')
shp_state = gp.read_file('data/mexico/mge2014v6_2/mge2015v6_2.shp')
shp_munic = gp.read_file('data/mexico/mgm2014v6_2/mgm2015v6_2.shp')

# %%
shp_urban.loc[3396]
# Out:
# CVE_ENT                                                    23
# CVE_MUN                                                   005
# CVE_LOC                                                  0001
# NOM_LOC                                               CancÃºn
# geometry    POLYGON ((-86.83937210783648 21.21085723087657...
# Name: 3396, dtype: object

# %%
def fix_encoding(s):
    for w, r in REPLACEMENTS.items():
        s = s.replace(w, r)
    return s

# %%
shp_urban.NOM_LOC = shp_urban.NOM_LOC.apply(fix_encoding)

# %%
shp_all = shp_urban.merge(shp_state.drop('geometry', axis=1)).merge(shp_munic.drop('geometry', axis=1))
# shp_all.drop('geometry', axis=1).to_csv('data/mexico/ent-mun-urban.csv')

# %% [markdown]
# ## match names in shapefiles and the crime statistics

# %%
cities = ['Acapulco, Guerrero', 'Cancún, Quintana Roo', 'Ciudad Juárez, Chihuahua', 'Chihuahua, Chihuahua', 
          'Cuernavaca, Morelos', 'Culiacán, Sinaloa', 'Guadalajara, Jalisco', 'Mexicali, Baja California', 
          'Monterrey, Nuevo León', 'Morelia, Michoacán', 'Nuevo Laredo, Tamaulipas', 'Oaxaca, Oaxaca', 'Tijuana, Baja California', 'Toluca, Estado de México', 'Villahermosa, Tabasco']

rows = []
for city in cities:
    cname, sname = city.split(',')
    sname = sname.strip()
    if cname == 'Ciudad Juárez':
        cname='Juárez'
    if sname == 'Estado de México':
        sname ='México'
    if sname == 'Michoacán':
        sname = 'Michoacán de Ocampo'
    rows.append(shp_all[(shp_all.NOM_LOC.str.contains(cname)) & (shp_all.NOM_ENT==sname)])

pd.concat(rows)
# Out:
#      CVE_ENT CVE_MUN CVE_LOC  \
# 742       12     001    0001
# 3396      23     005    0001
# 419       08     010    0005
# 454       08     037    0001
# 431       08     019    0001
# 2095      17     007    0001
# 3515      25     006    0001
# 1186      14     039    0001
# 48        02     002    0001
# 2280      19     039    0001
# 1943      16     053    0001
# 3815      28     027    0001
# 2373      20     067    0001
# 2882      20     549    0001
# 71        02     004    0001
# 1771      15     106    0001
# 3709      27     004    0001
#
#                                                 NOM_LOC  \
# 742                                  Acapulco de Juárez
# 3396                                             Cancún
# 419                                 Ejido Benito Juárez
# 454                                              Juárez
# 431                                           Chihuahua
# 2095                                         Cuernavaca
# 3515                                   Culiacán Rosales
# 1186                                        Guadalajara
# 48                                             Mexicali
# 2280                                          Monterrey
# 1943                                            Morelia
# 3815                                       Nuevo Laredo
# 2373                                   Oaxaca de Juárez
# 2882  Heroica Villa Tezoatlán de Segura y Luna, Cuna...
# 71                                              Tijuana
# 1771                                    Toluca de Lerdo
# 3709                                       Villahermosa
#
#                                                geometry              NOM_ENT  \
# 742   POLYGON ((-99.9395455851606 16.88883286234676,...             Guerrero
# 3396  POLYGON ((-86.83937210783648 21.21085723087657...         Quintana Roo
# 419   POLYGON ((-106.8835978923289 30.16639121458292...            Chihuahua
# 454   (POLYGON ((-106.4025488769291 31.5450063380720...            Chihuahua
# 431   (POLYGON ((-106.1628344308643 28.5909839381582...            Chihuahua
# 2095  POLYGON ((-99.25852772267621 19.00069855369537...              Morelos
# 3515  (POLYGON ((-107.420703891971 24.74156052279994...              Sinaloa
# 1186  POLYGON ((-103.3135014151582 20.74374155402955...              Jalisco
# 48    POLYGON ((-115.4003165851423 32.67198258432887...      Baja California
# 2280  POLYGON ((-100.4206058097103 25.74422449616361...           Nuevo León
# 1943  POLYGON ((-101.2098173996532 19.75286704607737...  Michoacán de Ocampo
# 3815  (POLYGON ((-99.5027761080309 27.41979446244454...           Tamaulipas
# 2373  POLYGON ((-96.76111883096922 17.13329393826467...               Oaxaca
# 2882  POLYGON ((-97.80531359984275 17.65452409161361...               Oaxaca
# 71    POLYGON ((-116.8755092151781 32.55543973805351...      Baja California
# 1771  POLYGON ((-99.63361744638803 19.34482309231191...               México
# 3709  POLYGON ((-92.89835407737871 18.04130872331899...              Tabasco
#
#                                                 NOM_MUN concat
# 742                                  Acapulco de Juárez  12001
# 3396                                      Benito Juárez  23005
# 419                                        Buenaventura  08010
# 454                                              Juárez  08037
# 431                                           Chihuahua  08019
# 2095                                         Cuernavaca  17007
# 3515                                           Culiacán  25006
# 1186                                        Guadalajara  14039
# 48                                             Mexicali  02002
# 2280                                          Monterrey  19039
# 1943                                            Morelia  16053
# 3815                                       Nuevo Laredo  28027
# 2373                                   Oaxaca de Juárez  20067
# 2882  Heroica Villa Tezoatlán de Segura y Luna, Cuna...  20549
# 71                                              Tijuana  02004
# 1771                                             Toluca  15106
# 3709                                             Centro  27004

# %%
# mannually removed 2 lines from above
idx = [742, 3396, 454, 431, 2095, 3515, 1186, 48, 2280, 1943, 3815, 2373, 71, 1771, 3709]
# shp_all.loc[idx]

# %%
pairs = []
for i in range(len(idx)):
    row = shp_all.loc[idx[i]]
    pairs.append({'In crime statistics': cities[i], 'in shapefile': '%s, %s' % (row.NOM_LOC, row.NOM_ENT)})
pd.DataFrame(pairs)
# Out:
#           In crime statistics                  in shapefile
# 0          Acapulco, Guerrero  Acapulco de Juárez, Guerrero
# 1        Cancún, Quintana Roo          Cancún, Quintana Roo
# 2    Ciudad Juárez, Chihuahua             Juárez, Chihuahua
# 3        Chihuahua, Chihuahua          Chihuahua, Chihuahua
# 4         Cuernavaca, Morelos           Cuernavaca, Morelos
# 5           Culiacán, Sinaloa     Culiacán Rosales, Sinaloa
# 6        Guadalajara, Jalisco          Guadalajara, Jalisco
# 7   Mexicali, Baja California     Mexicali, Baja California
# 8       Monterrey, Nuevo León         Monterrey, Nuevo León
# 9          Morelia, Michoacán  Morelia, Michoacán de Ocampo
# 10   Nuevo Laredo, Tamaulipas      Nuevo Laredo, Tamaulipas
# 11             Oaxaca, Oaxaca      Oaxaca de Juárez, Oaxaca
# 12   Tijuana, Baja California      Tijuana, Baja California
# 13   Toluca, Estado de México       Toluca de Lerdo, México
# 14      Villahermosa, Tabasco         Villahermosa, Tabasco

# %% [markdown]
# ## find the boundary for mexico city

# %%
target_states = ('Distrito Federal', 'México')
shp_state[shp_state.NOM_ENT.isin(('Distrito Federal', 'México'))]
# Out:
#    CVE_ENT           NOM_ENT  \
# 8       09  Distrito Federal
# 14      15            México
#
#                                              geometry
# 8   POLYGON ((-99.11124113799997 19.56149776900003...
# 14  POLYGON ((-99.91236793799999 20.28562618500007...

# %%
shp_all[shp_all.CVE_ENT.isin(['09','15'])]
# Out:
#      CVE_ENT CVE_MUN CVE_LOC                          NOM_LOC  \
# 495       09     002    0001                     Azcapotzalco
# 496       09     003    0001                         Coyoacán
# 497       09     004    0001            Cuajimalpa de Morelos
# 498       09     004    0020             San Lorenzo Acopilco
# 499       09     005    0001                Gustavo A. Madero
# 500       09     006    0001                        Iztacalco
# 501       09     007    0001                       Iztapalapa
# 502       09     008    0001           La Magdalena Contreras
# 503       09     009    0001                 Villa Milpa Alta
# 504       09     009    0011             San Antonio Tecómitl
# 505       09     009    0015          San Bartolomé Xicomulco
# 506       09     009    0017            San Francisco Tecoxpa
# 507       09     009    0024              San Pablo Oztotepec
# 508       09     009    0029                San Pedro Atocpan
# 509       09     009    0033          San Salvador Cuauhtenco
# 510       09     009    0036             Santa Ana Tlacotenco
# 511       09     009    0152           San Lorenzo Tlacoyucan
# 512       09     009    0300              San Nicolás Tetelco
# 513       09     010    0001                  Ãlvaro Obregón
# 514       09     011    0001                          Tláhuac
# 515       09     011    0011               San Andrés Mixquic
# 516       09     011    0021               San Juan Ixtayopan
# 517       09     011    0024              San Nicolás Tetelco
# 518       09     011    0026      Santa Catarina Yecahuitzotl
# 519       09     012    0001                          Tlalpan
# 520       09     012    0019               Parres (El Guarda)
# 521       09     012    0026                San Miguel Ajusco
# 522       09     012    0027              San Miguel Topilejo
# 523       09     013    0001                       Xochimilco
# 524       09     014    0001                    Benito Juárez
# ...      ...     ...     ...                              ...
# 1827      15     118    0058          San Juan de las Huertas
# 1828      15     118    0059     Ejido San Lorenzo Cuauhtenco
# 1829      15     118    0060                San Luis Mextepec
# 1830      15     118    0064            Santa Cruz Cuauhtenco
# 1831      15     118    0067            Santa María del Monte
# 1832      15     118    0075                          Tejalpa
# 1833      15     118    0087                 Barrio de México
# 1834      15     118    0134        Conjunto Urbano la Loma I
# 1835      15     119    0001                      Zumpahuacán
# 1836      15     120    0001               Zumpango de Ocampo
# 1837      15     120    0013      Santa María Cuevas (Cuevas)
# 1838      15     120    0014              Arbolada los Sauces
# 1839      15     120    0023  Colonia Lázaro Cárdenas del Río
# 1840      15     120    0041          San Bartolo Cuautlalpan
# 1841      15     120    0045              San José de la Loma
# 1842      15     120    0046             San Juan Zitlaltepec
# 1843      15     120    0054                    San Sebastián
# 1844      15     120    0056                      Santa Lucía
# 1845      15     120    0057              Colonia Santa Lucía
# 1846      15     120    0175      Fraccionamiento la Trinidad
# 1847      15     120    0198               Paseos de San Juan
# 1848      15     120    0204              Villas de la Laguna
# 1849      15     121    0001               Cuautitlán Izcalli
# 1850      15     121    0020                         Huilango
# 1851      15     122    0001                             Xico
# 1852      15     123    0001                   Villa Luvianos
# 1853      15     124    0001       San José del Rincón Centro
# 1854      15     124    0054  Guarda la Lagunita (Las Canoas)
# 1855      15     124    0107          San Miguel Agua Bendita
# 1856      15     125    0001            Santa María Tonanitla
#
#                                                geometry           NOM_ENT  \
# 495   POLYGON ((-99.18244684564536 19.50756095367512...  Distrito Federal
# 496   POLYGON ((-99.13983600033112 19.35691759966755...  Distrito Federal
# 497   POLYGON ((-99.25737566235688 19.4011202306142,...  Distrito Federal
# 498   POLYGON ((-99.32324335439728 19.34193038517918...  Distrito Federal
# 499   POLYGON ((-99.11124113766834 19.56149776910684...  Distrito Federal
# 500   POLYGON ((-99.05578649235269 19.4221410920378,...  Distrito Federal
# 501   POLYGON ((-99.01832866163841 19.3826088311327,...  Distrito Federal
# 502   (POLYGON ((-99.24445636876635 19.2762142001253...  Distrito Federal
# 503   POLYGON ((-99.02828118532841 19.20528638535842...  Distrito Federal
# 504   POLYGON ((-98.99717701540692 19.22747256940363...  Distrito Federal
# 505   POLYGON ((-99.06616315430608 19.21073064630235...  Distrito Federal
# 506   POLYGON ((-98.99935667706893 19.20580287680139...  Distrito Federal
# 507   POLYGON ((-99.07617463125422 19.19220187731486...  Distrito Federal
# 508   POLYGON ((-99.0560863227256 19.20316169205847,...  Distrito Federal
# 509   POLYGON ((-99.09633110839388 19.20130143091637...  Distrito Federal
# 510   POLYGON ((-98.99859619955492 19.18411619960295...  Distrito Federal
# 511   POLYGON ((-99.03261361532606 19.18346000027884...  Distrito Federal
# 512   POLYGON ((-98.97434953830054 19.21444313764073...  Distrito Federal
# 513   POLYGON ((-99.1890551692606 19.39559033802374,...  Distrito Federal
# 514   POLYGON ((-99.03935026230471 19.3143781227522,...  Distrito Federal
# 515   POLYGON ((-98.9685865081608 19.23221795369568,...  Distrito Federal
# 516   POLYGON ((-98.99921021527916 19.24092438485252...  Distrito Federal
# 517   POLYGON ((-98.96690823112993 19.22177299992404...  Distrito Federal
# 518   POLYGON ((-98.96374688031426 19.31214147195141...  Distrito Federal
# 519   POLYGON ((-99.20575216942706 19.30568187731683...  Distrito Federal
# 520   POLYGON ((-99.17972798465871 19.12995581540861...  Distrito Federal
# 521   POLYGON ((-99.18135240039294 19.21769841544955...  Distrito Federal
# 522   POLYGON ((-99.15460844592303 19.2118161999577,...  Distrito Federal
# 523   (POLYGON ((-99.10960203150853 19.2037551232004...  Distrito Federal
# 524   POLYGON ((-99.13658764640275 19.40281181491338...  Distrito Federal
# ...                                                 ...               ...
# 1827  POLYGON ((-99.75104675440417 19.26427726208601...            México
# 1828  POLYGON ((-99.75879690765112 19.31338878486457...            México
# 1829  POLYGON ((-99.70656918541954 19.30797676911266...            México
# 1830  POLYGON ((-99.72106444556766 19.25510950839714...            México
# 1831  POLYGON ((-99.81537941522777 19.29257647712279...            México
# 1832  POLYGON ((-99.77211538511688 19.25725652287031...            México
# 1833  POLYGON ((-99.82085378457447 19.28814999962282...            México
# 1834  POLYGON ((-99.73702726169876 19.32950641478925...            México
# 1835  POLYGON ((-99.5840760620606 18.83408020044095,...            México
# 1836  POLYGON ((-99.07093686184663 19.79181652291425...            México
# 1837  POLYGON ((-99.08739973790756 19.87003335365642...            México
# 1838  POLYGON ((-99.0470956149706 19.80905276917002,...            México
# 1839  POLYGON ((-99.13581123110339 19.82781132303415...            México
# 1840  POLYGON ((-99.00069420007725 19.82165470819825...            México
# 1841  POLYGON ((-99.1559070768501 19.81749258461514,...            México
# 1842  POLYGON ((-99.13863435409212 19.8209392921147,...            México
# 1843  POLYGON ((-99.04727872323446 19.78621312333701...            México
# 1844  POLYGON ((-98.98090078464344 19.75022504564942...            México
# 1845  POLYGON ((-99.01794892290445 19.77138759975799...            México
# 1846  POLYGON ((-99.08187912272331 19.83726187663433...            México
# 1847  POLYGON ((-99.00989513785032 19.78641899973712...            México
# 1848  POLYGON ((-99.09085449164144 19.82910024577978...            México
# 1849  POLYGON ((-99.18848198455589 19.72871115429638...            México
# 1850  POLYGON ((-99.24596223406979 19.69349103288494...            México
# 1851  POLYGON ((-98.95303009206503 19.33462866178337...            México
# 1852  POLYGON ((-100.2943432922091 18.92904975424284...            México
# 1853  POLYGON ((-100.1458400917468 19.66139207698279...            México
# 1854  POLYGON ((-100.1273384148359 19.70224987742995...            México
# 1855  POLYGON ((-100.0732973850662 19.63640187694511...            México
# 1856  POLYGON ((-99.04660407701653 19.69222261468195...            México
#
#                           NOM_MUN concat
# 495                  Azcapotzalco  09002
# 496                      Coyoacán  09003
# 497         Cuajimalpa de Morelos  09004
# 498         Cuajimalpa de Morelos  09004
# 499             Gustavo A. Madero  09005
# 500                     Iztacalco  09006
# 501                    Iztapalapa  09007
# 502        La Magdalena Contreras  09008
# 503                    Milpa Alta  09009
# 504                    Milpa Alta  09009
# 505                    Milpa Alta  09009
# 506                    Milpa Alta  09009
# 507                    Milpa Alta  09009
# 508                    Milpa Alta  09009
# 509                    Milpa Alta  09009
# 510                    Milpa Alta  09009
# 511                    Milpa Alta  09009
# 512                    Milpa Alta  09009
# 513                Álvaro Obregón  09010
# 514                       Tláhuac  09011
# 515                       Tláhuac  09011
# 516                       Tláhuac  09011
# 517                       Tláhuac  09011
# 518                       Tláhuac  09011
# 519                       Tlalpan  09012
# 520                       Tlalpan  09012
# 521                       Tlalpan  09012
# 522                       Tlalpan  09012
# 523                    Xochimilco  09013
# 524                 Benito Juárez  09014
# ...                           ...    ...
# 1827                 Zinacantepec  15118
# 1828                 Zinacantepec  15118
# 1829                 Zinacantepec  15118
# 1830                 Zinacantepec  15118
# 1831                 Zinacantepec  15118
# 1832                 Zinacantepec  15118
# 1833                 Zinacantepec  15118
# 1834                 Zinacantepec  15118
# 1835                  Zumpahuacán  15119
# 1836                     Zumpango  15120
# 1837                     Zumpango  15120
# 1838                     Zumpango  15120
# 1839                     Zumpango  15120
# 1840                     Zumpango  15120
# 1841                     Zumpango  15120
# 1842                     Zumpango  15120
# 1843                     Zumpango  15120
# 1844                     Zumpango  15120
# 1845                     Zumpango  15120
# 1846                     Zumpango  15120
# 1847                     Zumpango  15120
# 1848                     Zumpango  15120
# 1849           Cuautitlán Izcalli  15121
# 1850           Cuautitlán Izcalli  15121
# 1851  Valle de Chalco Solidaridad  15122
# 1852                     Luvianos  15123
# 1853          San José del Rincón  15124
# 1854          San José del Rincón  15124
# 1855          San José del Rincón  15124
# 1856                    Tonanitla  15125
#
# [521 rows x 8 columns]

# %%
# http://www.conapo.gob.mx/es/CONAPO/Datos_Abiertos_Delimitacion_de_Zonas_Metropolitanas
metro = gp.read_file('data/mexico/Mapa_de_delimitacion_de_zonas_metropolitanas_2010/ZM_2010.shp').to_crs(epsg=4326)

# %%
some_map = folium.Map(location=[19.381495, -99.139095], zoom_start=10)
geojson_per_row(shp_state[shp_state.CVE_ENT=='09'], 'Distrito Federal', color='yellow',some_map=some_map)
geojson_per_row(shp_munic[shp_munic.CVE_ENT=='09'], 'Distrito Federal munic', color='green',some_map=some_map)

# geojson_per_row(shp_state[shp_state.CVE_ENT=='15'], 'Mexico state', color='green',some_map=some_map)
geojson_per_row(shp_all[shp_all.CVE_ENT.isin(['09'])], 'Mexico related urban', tip_cols=['NOM_ENT', 'NOM_MUN', 'NOM_LOC'], some_map=some_map)

geojson_per_row(metro[metro['NOM_SUN']=='Valle de M‚xico'], 'metro area', tip_cols=['NOM_ENT', 'NOM_MUN', 'NOM_SUN'], color='purple', some_map=some_map)
folium.LayerControl().add_to(some_map)
some_map.save('tmp/where is the mexico city.html')

# %% [markdown]
# ### decide to go for urban area in Distrito Federal

# %% [markdown]
# ## draw maps

# %%
some_map = folium.Map(location=[24.062199, -102.870324], zoom_start=6)
for i, row in enumerate(shp_all.loc[idx].itertuples()):
    
    if row.geometry.boundary.type=='MultiLineString':
        lines = row.geometry.boundary
    else:
        lines= [row.geometry.boundary]
    for _,line in enumerate(lines):
        tip = 'In crime statistics: %s <br> in shapefile: Localidades Urbanas: %s, Estatales: %s' %(cities[i], row.NOM_LOC, row.NOM_ENT)
        a = folium.PolyLine(
            locations=[(lat,lon) for lon,lat in line.coords], fill_color='blue', 
            tooltip=tip,
            popup=tip
        )
        a.add_to(some_map)
    
some_map.save('mexico cities.html')

# %%
some_map = folium.Map(location=[24.062199, -102.870324], zoom_start=6)
for i, row in enumerate(shp_state.itertuples()):
#     if not row.NOM_ENT in ('Distrito Federal', 'México'):
#         continue
    if row.geometry.boundary.type=='MultiLineString':
        lines = row.geometry.boundary
    else:
        lines= [row.geometry.boundary]
    for _,line in enumerate(lines):
        tip = '%s' %(row.NOM_ENT)
        a = folium.Polygon(
            locations=[(lat,lon) for lon,lat in line.coords], 
            tooltip=tip,
            popup=tip, fill_color='blue'
        )
        a.add_to(some_map)
    
some_map.save('tmp/mexico states.html')
